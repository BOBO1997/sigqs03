# %% [markdown]
# # Modified Grover operator for quantum amplitude estimation
#
#
# ## Contributors
#
# Based on the paper [Modified Grover operator for amplitude estimation](https://arxiv.org/abs/2010.11656).
#
# Shumpei Uno, Yohichi Suzuki, Keigo Hisanaga, Rudy Raymond, Tomoki Tanaka, Tamiya Onodera, and Naoki Yamamoto.
#
#
# ## Summary
#
# This notebook contains experiments for performing amplitude estimation without inverse Quantum Fourier Transform (QFT) and controlled Q-operators (a.k.a. Grover operators).
# It is known that without QFT and such controlled operators, the number of two-qubit gates (e.g., CNOT gates) required for running amplitude estimation can be reduced, and hence may be more appropriate to run quantum algorithms on Noisy Intermediate Scale Quantum (NISQ) devices.
# Here, the Grover operator used here is the modified one provided by the paper above, which would reach the higher accuracy under the depolarization error.

# %% [markdown]
# ## Modified Amplitude Amplification Operator
#
# ### Operator
#
# The modified amplitude amplification operator is defined as:
# $$Q=U_{0} A^{\dagger} U_{f} A$$
# while the conventional amplitude amplification operator is like:
# $$G=A U_{0} A^{\dagger} U_{f}$$
#
# ### Result after $m$ Iterations
# Application of $Q^m$ on the initial
# state $\left|0\right>^{n+1}$ produces
# \begin{eqnarray}
# \left|\psi_{Q}\left(\theta, N_{\mathrm{q}}\right)\right\rangle:=Q^{m}|0\rangle_{n+1}=\cos \left(N_{\mathrm{q}} \theta\right)|0\rangle_{n+1}+\sin \left(N_{\mathrm{q}} \theta\right)|\phi\rangle_{n+1}
# \end{eqnarray}
# where
# \begin{eqnarray}
# \begin{aligned}
# |\phi\rangle_{n+1} &=A^{\dagger}\left(-\sin \theta\left|\psi_{0}\right\rangle_{n}|0\rangle+\cos \theta\left|\psi_{1}\right\rangle_{n}|1\rangle\right) \\
# &=\frac{1}{\sin 2 \theta}(Q-\cos 2 \theta)|0\rangle_{n+1}
# \end{aligned}
# \end{eqnarray}
# and $N_q = 2m$.
#
# ### Measurement Operators
# The set of measurement operators
# $$E_{Q, 0}=|0\rangle_{n+1}\left\langle\left. 0\right|_{n+1}\right.$$
# $$E_{Q, 1}=\mathbf{I}_{n+1}-E_{Q, 0}$$
# distinguishes whether all qubits are 0 or not.
#
# Measuring the state $\left|\psi_{Q}\left(\theta, N_{\mathrm{q}}\right)\right\rangle$ via $\left\{E_{Q, 0}, E_{Q, 1}\right\}$ yields the probability distribution as
# \begin{eqnarray}
# \begin{array}{l}
# p_{Q}\left(0 ; \theta, N_{\mathrm{q}}\right)=\cos ^{2}\left(N_{\mathrm{q}} \theta\right) \\
# p_{Q}\left(1 ; \theta, N_{\mathrm{q}}\right)=\sin ^{2}\left(N_{\mathrm{q}} \theta\right)
# \end{array}
# \end{eqnarray}
#
#
# ### Circuit Implementation
# For the label $\left|x\right>_n$ in computational basis, the operator $A$ maps $\left|0\right>_n\left|0\right>$ to
# <!-- $\left|x\right>_n\left|0\right>$ to
# \begin{eqnarray}
# A \left|x\right>_n\left|0\right>
# &=& \left|x\right>_n \left( \sqrt{f(x)} \left|1\right> + \sqrt{1-f(x)} \left|0\right>\right) \\
# &=& \left|x\right>_n \left( \sqrt{a} \left|1\right> + \sqrt{1-a} \left|0\right>\right)\\
# &=& \left|x\right>_n \left( \sin\theta \left|1\right> + \cos\theta \left|0\right>\right)
# \end{eqnarray}
# -->
# $$A|0\rangle_{n+1}=\cos \theta\left|\psi_{0}\right\rangle_{n}|0\rangle+\sin \theta\left|\psi_{1}\right\rangle_{n}|1\rangle$$
# where $a=\sin^2\theta$.
# Here, $A$ can be realized with controlled-$Y$ rotation gates.

# %% [markdown]
# ## Introduction
#
# We consider applying amplitude estimation, one of the most popular quantum algorithms, for Monte Carlo integration, a problem which is essential for financial applications. The purpose of Monte Carlo integration is to compute the expected value of a real-valued function $f$. Here, for simplicity we assume $f$ takes an $n$-bit input $x \in \{0,1\}^n$, $0 \le f(x) \le 1$, and the probability of $f(x)$ is $p(x)$. Then, the expected value is
# $$
# \mathbb{E}[f(x)] = \sum_{x=0}^{2^n-1} p(x) f(x)
# $$
#
# To compute the Monte Carlo integration of $f$, let us assume that quantum circuits $\mathcal{P}$ and $\mathcal{R}$, that perform the following transformation, are given.
# \begin{eqnarray}
# \mathcal{P} \left|0\right>_n &=& \sum_{x} \sqrt{p(x)} \left|x\right>_n\\
# \mathcal{R} \left|x\right>_n\left|0\right> &=& \left|x\right>_n \left( \sqrt{f(x)} \left|1\right> + \sqrt{1-f(x)} \left|0\right>\right)
# \end{eqnarray}
# The former is for creating probability distribution $p(\cdot)$, and the latter for computing $f(\cdot)$.

# %% [markdown]
# ## Integral of sine functions
#
# Following Section 4.2 of ["Amplitude Estimation without Phase Estimation", by Suzuki et al.](https://arxiv.org/abs/1904.10246), we consider the following integral
# $$
# \mathcal{I} = \frac{1}{b_\mbox{max}}\int_{0}^{b_\mbox{max}} \sin^2{x}~dx = \frac 1 {b_{max}}\left(\frac {b_{max}} 2 - \frac 1 4 \sin(2b_{max})\right)
# $$
# which is approximated with the following summation
#
# $$
# \mathcal{S} = \sum_{x=0}^{2^n-1} \frac{1}{2^n} \sin^2{\left(  \frac{\left(x+1/2\right)b_{\mbox{max}}}{2^n}  \right)}.
# $$
#
# This means, we the quantum circuits $\mathcal{P}$ and $\mathcal{R}$ are
# \begin{eqnarray}
# \mathcal{P} \left|0\right>_n \left|0\right> &=& \frac{1}{\sqrt{2^n}} \sum_{x} \left|x\right>_n \left|0\right>\\
# \mathcal{R} \left|x\right>_n\left|0\right> &=& \left|x\right>_n \left(    \sin{\left(  \frac{\left(x+1/2\right)b_{\mbox{max}}}{2^n}  \right)} \left|1\right> +   \cos{\left(  \frac{\left(x+1/2\right)b_{\mbox{max}}}{2^n}  \right)} \left|0\right>\right).
# \end{eqnarray}
#
# $\mathcal{P}$ can be realized with Hadamard gates, and $\mathcal{R}$ with controlled-$Y$ rotation gates.

# %% [markdown]
# ### Approximating the integral
#
# It is easy to see that as we use large $n$ (i.e., more qubits) and thus larger $b_{\mbox{max}}$, we can approximate the integral better as illustrated below.

# %%
import math

b_max = math.pi / 100  # upper limit of integral # 5
nbit = 7  # change this value to get discretized result closer to analytical results # 3

analyticResult = (b_max / 2.0 - math.sin(2 * b_max) / 4.0 ) / b_max  # the target integral can be analytically solved
print("Analytical Result:", analyticResult)

ndiv = 2**nbit  #number of discretization 
discretizedResult = 0.0
for i in range(ndiv):
    discretizedResult += math.sin(b_max / ndiv * (i + 0.5))**2
discretizedResult = discretizedResult / ndiv
print("Discretized Result:", discretizedResult)
# Out:
# Analytical Result: 0.00032892188007938847
# Discretized Result: 0.00032891686344125806

# %% [markdown]
# ### Implementing circuits for Monte Carlo integration of sine functions
#
# Below are the functions to compute $\mathcal{P}$, $\mathcal{R}$, and their inverses.

# %%
# OK
def P(qc, qx, nbit):
    """
        Generating uniform probability distribution
            qc: quantum circuit
            qx: quantum register
            nbit: number of qubits
        The inverse of P = P
    """
    qc.h(qx)

# OK
def R(qc, qx, qx_measure, nbit, b_max):
    """
        Computing the integral function f()
            qc: quantum circuit
            qx: quantum register
            qx_measure: quantum register for measurement
            nbit: number of qubits
            b_max: upper limit of integral            
    """
    qc.ry(b_max / 2**nbit * 2 * 0.5, qx_measure)
    for i in range(nbit):
        qc.cu3(2**i * b_max / 2**nbit * 2, 0, 0, qx[i], qx_measure[0])

# OK
def Rinv(qc, qx, qx_measure, nbit, b_max):
    """3
        The inverse of R
            qc: quantum circuit
            qx: quantum register
            qx_measure : quantum register for measurement
            nbit: number of qubits
            b_max: upper limit of integral
    """
    for i in range(nbit)[::-1]:
        qc.cu3(-2**i * b_max / 2**nbit * 2, 0, 0, qx[i], qx_measure[0])
    qc.ry(-b_max / 2**nbit * 2 * 0.5, qx_measure)

# %% [markdown]
# ### Grover Operators for Amplitude Estimation
#
# We can easily build quantum circuits for fast computation of the Monte Carlo integration as below. Here, we show functions to construct quantum circuits running with simulators. Running them on real devices should be easy by adjusting the parameters of the functions.

# %%
import sys
sys.path.append('../libmitigation')

# %%
#Preparing qiskit environment
from qiskit import ClassicalRegister, QuantumRegister, QuantumCircuit
from qiskit import execute
from qiskit import IBMQ
from qiskit import Aer
from scipy import optimize
import sys, time
import mpmath as mp
import numpy as np
import matplotlib.pyplot as plt
import random
random.seed(10)
# Out:
# /Users/yangbo/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/qiskit/__init__.py:67: DeprecationWarning: Using Qiskit with Python 3.6 is deprecated as of the 0.17.0 release. Support for running Qiskit with Python 3.6 will be removed in a future release.
#   "future release.", DeprecationWarning)

# %%
from qiskit.providers.aer.noise import NoiseModel
from qiskit.providers.aer.noise import QuantumError, ReadoutError
from qiskit.providers.aer.noise import depolarizing_error
import qiskit.ignis.mitigation as mit
from qiskit.ignis.mitigation.measurement import tensored_meas_cal, TensoredMeasFitter
import importlib
from inv_sgs import InvSGS
from inv_s_sgs import InvSSGS
from inv_lm_sgs import InvLMSGS
from inv_s_lm_sgs import InvSLMSGS
from inv_s_lm0_sgs import InvSLM0SGS
from sgs_algorithm import sgs_algorithm

# %%
# OK
def reflect(qc, qx, qx_measure, qx_ancilla, nbit, b_max):
    """
        Computing reflection operator (I - 2|0><0|)
            qc: quantum circuit
            qx: quantum register
            qx_measure: quantum register for measurement
            qx_ancilla: temporal quantum register for decomposing multi controlled NOT gate
            nbit: number of qubits
            b_max: upper limit of integral
    """
    for i in range(nbit):
        qc.x(qx[i])
    qc.x(qx_measure[0])
    qc.barrier()    #format the circuits visualization
    # multi_control_NOT(qc, qx, qx_measure, qx_ancilla, nbit, b_max)
    qc.h(qx_measure)
    qc.mcx(qx, qx_measure)
    qc.h(qx_measure)
    qc.barrier()    #format the circuits visualization
    qc.x(qx_measure[0])
    for i in range(nbit):
        qc.x(qx[i])


# OK
# This is to implement Grover Operator
def Q_grover(qc, qx, qx_measure, qx_ancilla, nbit, b_max):
    """
        The Grover operator: R P (I - 2|0><0|) P^+ R^+ U_psi_0 
            qc: quantum circuit
            qx: quantum register
            qx_measure: quantum register for measurement
            qx_ancilla: temporal quantum register for decomposing multi controlled NOT gate
            nbit: number of qubits
            b_max: upper limit of integral
    """
    P(qc, qx, nbit)
    qc.barrier()    #format the circuits visualization
    R(qc, qx, qx_measure, nbit, b_max)
    qc.z(qx_measure[0])
    Rinv(qc, qx, qx_measure, nbit, b_max)
    qc.barrier()    #format the circuits visualization
    P(qc, qx, nbit)
    qc.barrier()    #format the circuits visualization
    reflect(qc, qx, qx_measure, qx_ancilla, nbit, b_max)
    qc.barrier()    #format the circuits visualization

# %% [markdown]
# ## Amplitude Estimation without Phase Estimation
#
# To run the amplitude estimation without phase estimation of [Suzuki et al.](https://arxiv.org/abs/1904.10246), we must create quantum circuits that run Grover operators with various number of iterations. The function for creating such circuits is as the following.

# %%
# OK
def create_grover_circuit(numebr_grover_list, nbit, b_max):
    """
        To generate quantum circuits running Grover operators with number of iterations in number_grover_list
            numebr_grover_list: list of number of Grover operators
            nbit: number of qubits (2**nbit = ndiv is the number of discretization in the Monte Carlo integration)
            b_max: upper limit of integral
        Return:
            qc_list: quantum circuits with Grover operators as in number_grover_list
    """
    qc_list = []
    for igrover in range(len(numebr_grover_list)):
        qx = QuantumRegister(nbit)
        qx_measure = QuantumRegister(1)
        cr = ClassicalRegister(nbit + 1) # modified grover
        qc = QuantumCircuit(qx, qx_measure, cr)
        qx_ancilla = QuantumRegister(1)
        for ikAA in range(numebr_grover_list[igrover]):
            Q_grover(qc, qx, qx_measure, qx_ancilla, nbit, b_max)
        qc.measure(qx, cr[:-1]) # modified grover
        qc.measure(qx_measure, cr[-1])# modified grover
        qc_list.append(qc)
    return qc_list

# %% [markdown]
# For example, quantum circuit with two Grover operators is shown below.

# %%
qc_list = create_grover_circuit([2], nbit, b_max)
my_style = {'usepiformat': True, 'cregbundle': True,'compress': True }
qc_list[0].draw(output="mpl", style=my_style, plot_barriers=False )
# Out:
# /Users/yangbo/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: The QuantumCircuit.cu3 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use the QuantumCircuit.cu method instead, where cu3(ϴ,φ,λ) = cu(ϴ,φ,λ,0).
# /Users/yangbo/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/qiskit/visualization/matplotlib.py:291: DeprecationWarning: style option/s (usepiformat, cregbundle, compress) is/are not supported
#   set_style(current_style, style)

# %% [markdown]
# We also need a helper function to simultaneously run the quantum circuits that are returned by the above functions, as below.

# %%
# OK
def run_grover(qc_list, number_grover_list, shots_list, backend, noise_model=None):
    """
        Run the quantum circuits returned by create_grover_circuit()
            qc_list: list of quantum circuits
            numebr_grover_list: list of number of Grover operators
            shots_list:  list of number of shots
            backend: name of backends
        
        Return:
            hit_list: list of count of obserbving "1" for qc_list
    """
    counts_list = []
    for k in range(len(number_grover_list)):
        t1 = time.time()
        print(k,"th round with", number_grover_list[k],"oracles")
        job = execute(qc_list[k], backend=backend, shots=shots_list[k], noise_model=noise_model)
        lapse = 0
        interval = 0.00001
        time.sleep(interval)
        while job.status().name != 'DONE':
            time.sleep(interval)
            lapse += 1
        counts_list.append(job.result().get_counts(qc_list[k]))
        t2 = time.time()
        print(t2 - t1, "s")
    return counts_list

# %%
def make_hit_list(counts_list):
    hit_list = []
    for k in range(len(counts_list)):
        hits = counts_list[k].get("0"*(nbit+1), 0)
        hit_list.append(hits)
    return hit_list

# %% [markdown]
# ## Testing the algorithm with simulators
#
# Let us run the algorithm with simulators

# %%
#setting the number of shots and Grover operators.

# number_grover_list = [0, 1, 2, 4, 8, 16, 32] # , 64, 128, 256]  # list of number of Grover operators
number_grover_list = [i for i in range(100)]
shots_list = [100] * len(number_grover_list) # list of number of shots
if len(shots_list) != len(number_grover_list):
    raise Exception(
        'The length of shots_list should be equal to the length of number_grover_list.'
    )

backend = Aer.get_backend('qasm_simulator')

# %%
noise_model = NoiseModel()
for qi in range(nbit+1):
    if qi >= 0:
        read_err = ReadoutError([[0.95, 0.05],[0.05,0.95]])
        noise_model.add_readout_error(read_err, [qi])

# %% [markdown]
# Finally, we can run the algorithm as below:

# %%
qc_list = create_grover_circuit(number_grover_list, nbit,b_max)  # list of Grover circuits

# %%
counts_list = run_grover(qc_list, number_grover_list, shots_list, backend, noise_model=noise_model)  # list of number of grover operators
# Out:
# 0 th round with 0 oracles
# 0.8218231201171875 s
# 1 th round with 1 oracles
# 0.03407120704650879 s
# 2 th round with 2 oracles
# 0.04219698905944824 s
# 3 th round with 3 oracles
# 0.07768416404724121 s
# 4 th round with 4 oracles
# 0.04628896713256836 s
# 5 th round with 5 oracles
# 0.04590177536010742 s
# 6 th round with 6 oracles
# 0.06172990798950195 s
# 7 th round with 7 oracles
# 0.06283402442932129 s
# 8 th round with 8 oracles
# 0.08058786392211914 s
# 9 th round with 9 oracles
# 0.10682082176208496 s
# 10 th round with 10 oracles
# 0.10841202735900879 s
# 11 th round with 11 oracles
# 0.11321496963500977 s
# 12 th round with 12 oracles
# 0.12057709693908691 s
# 13 th round with 13 oracles
# 0.20606589317321777 s
# 14 th round with 14 oracles
# 0.13487696647644043 s
# 15 th round with 15 oracles
# 0.1568279266357422 s
# 16 th round with 16 oracles
# 0.27408528327941895 s
# 17 th round with 17 oracles
# 0.2683568000793457 s
# 18 th round with 18 oracles
# 0.26258397102355957 s
# 19 th round with 19 oracles
# 0.2497420310974121 s
# 20 th round with 20 oracles
# 0.23934292793273926 s
# 21 th round with 21 oracles
# 0.19950604438781738 s
# 22 th round with 22 oracles
# 0.21327996253967285 s
# 23 th round with 23 oracles
# 0.5506250858306885 s
# 24 th round with 24 oracles
# 0.23067998886108398 s
# 25 th round with 25 oracles
# 0.26662111282348633 s
# 26 th round with 26 oracles
# 0.265758752822876 s
# 27 th round with 27 oracles
# 0.22980403900146484 s
# 28 th round with 28 oracles
# 0.2602519989013672 s
# 29 th round with 29 oracles
# 0.2718660831451416 s
# 30 th round with 30 oracles
# 0.24492502212524414 s
# 31 th round with 31 oracles
# 0.24878907203674316 s
# 32 th round with 32 oracles
# 0.2667088508605957 s
# 33 th round with 33 oracles
# 0.2760179042816162 s
# 34 th round with 34 oracles
# 0.27020907402038574 s
# 35 th round with 35 oracles
# 0.289686918258667 s
# 36 th round with 36 oracles
# 0.3839390277862549 s
# 37 th round with 37 oracles
# 0.31452488899230957 s
# 38 th round with 38 oracles
# 0.5117249488830566 s
# 39 th round with 39 oracles
# 0.35359883308410645 s
# 40 th round with 40 oracles
# 0.4922668933868408 s
# 41 th round with 41 oracles
# 0.653076171875 s
# 42 th round with 42 oracles
# 0.41062498092651367 s
# 43 th round with 43 oracles
# 0.4885728359222412 s
# 44 th round with 44 oracles
# 0.4692509174346924 s
# 45 th round with 45 oracles
# 0.4892551898956299 s
# 46 th round with 46 oracles
# 0.4436197280883789 s
# 47 th round with 47 oracles
# 0.5498149394989014 s
# 48 th round with 48 oracles
# 0.56778883934021 s
# 49 th round with 49 oracles
# 0.4470341205596924 s
# 50 th round with 50 oracles
# 0.429124116897583 s
# 51 th round with 51 oracles
# 0.44686198234558105 s
# 52 th round with 52 oracles
# 0.5057499408721924 s
# 53 th round with 53 oracles
# 0.7929787635803223 s
# 54 th round with 54 oracles
# 0.5629711151123047 s
# 55 th round with 55 oracles
# 0.5136861801147461 s
# 56 th round with 56 oracles
# 0.7932217121124268 s
# 57 th round with 57 oracles
# 0.7884411811828613 s
# 58 th round with 58 oracles
# 0.8735909461975098 s
# 59 th round with 59 oracles
# 0.7376348972320557 s
# 60 th round with 60 oracles
# 0.6745030879974365 s
# 61 th round with 61 oracles
# 0.6611928939819336 s
# 62 th round with 62 oracles
# 1.1007921695709229 s
# 63 th round with 63 oracles
# 0.6826589107513428 s
# 64 th round with 64 oracles
# 0.6850502490997314 s
# 65 th round with 65 oracles
# 0.6639139652252197 s
# 66 th round with 66 oracles
# 0.6970481872558594 s
# 67 th round with 67 oracles
# 0.7501251697540283 s
# 68 th round with 68 oracles
# 0.687006950378418 s
# 69 th round with 69 oracles
# 0.7675061225891113 s
# 70 th round with 70 oracles
# 1.3367199897766113 s
# 71 th round with 71 oracles
# 0.9836552143096924 s
# 72 th round with 72 oracles
# 1.1750259399414062 s
# 73 th round with 73 oracles
# 1.0794651508331299 s
# 74 th round with 74 oracles
# 1.2474119663238525 s
# 75 th round with 75 oracles
# 1.298410177230835 s
# 76 th round with 76 oracles
# 1.2859718799591064 s
# 77 th round with 77 oracles
# 1.854264259338379 s
# 78 th round with 78 oracles
# 1.3981907367706299 s
# 79 th round with 79 oracles
# 1.5296001434326172 s
# 80 th round with 80 oracles
# 1.639909029006958 s
# 81 th round with 81 oracles
# 1.8523008823394775 s
# 82 th round with 82 oracles
# 1.7501368522644043 s
# 83 th round with 83 oracles
# 1.9676830768585205 s
# 84 th round with 84 oracles
# 2.5067648887634277 s
# 85 th round with 85 oracles
# 1.5378620624542236 s
# 86 th round with 86 oracles
# 1.3999390602111816 s
# 87 th round with 87 oracles
# 1.5280990600585938 s
# 88 th round with 88 oracles
# 1.728926181793213 s
# 89 th round with 89 oracles
# 1.4037110805511475 s
# 90 th round with 90 oracles
# 1.920616865158081 s
# 91 th round with 91 oracles
# 1.5272188186645508 s
# 92 th round with 92 oracles
# 1.6202480792999268 s
# 93 th round with 93 oracles
# 2.0484042167663574 s
# 94 th round with 94 oracles
# 2.0843758583068848 s
# 95 th round with 95 oracles
# 2.281968116760254 s
# 96 th round with 96 oracles
# 2.656432867050171 s
# 97 th round with 97 oracles
# 2.5455989837646484 s
# 98 th round with 98 oracles
# 2.6725308895111084 s
# 99 th round with 99 oracles
# 2.3595409393310547 s

# %%
import pickle
with open("raw_result_p005_q005_piover100.pkl", "wb") as f:
    pickle.dump(counts_list, f)

# %%
import pickle
with open("raw_result_p005_q005_piover100.pkl", "rb") as f:
    counts_list = pickle.load(f)

# %%
hit_list = make_hit_list(counts_list)
print(hit_list)
# Out:
# [65, 68, 69, 52, 69, 63, 60, 64, 59, 56, 57, 62, 52, 59, 51, 45, 47, 51, 39, 39, 37, 36, 29, 31, 25, 29, 29, 18, 22, 12, 12, 10, 9, 10, 6, 8, 6, 8, 6, 5, 3, 5, 6, 2, 1, 0, 1, 4, 4, 2, 5, 7, 10, 11, 16, 13, 14, 17, 18, 23, 28, 20, 28, 29, 26, 35, 45, 33, 37, 49, 42, 53, 47, 55, 52, 63, 65, 58, 61, 67, 70, 56, 70, 67, 62, 63, 64, 57, 65, 70, 63, 64, 66, 58, 68, 58, 54, 55, 60, 59]

# %%
divide = 100
plt.plot(number_grover_list, hit_list, marker="o")
plt.plot(np.linspace(0,number_grover_list[-1], divide), divide * np.cos(2 * np.linspace(0,number_grover_list[-1], divide) * np.arccos(np.sqrt(discretizedResult))) ** 2)

# %%
shots = 8192
qr = QuantumRegister(nbit+1)
mit_pattern = [[i] for i in range(nbit+1)]
meas_calibs, state_labels = tensored_meas_cal(mit_pattern=mit_pattern, qr=qr, circlabel='mcal')
job = execute(meas_calibs, backend=Aer.get_backend('qasm_simulator'), shots=shots, noise_model=noise_model)
cal_results = job.result()
meas_fitter = TensoredMeasFitter(cal_results, mit_pattern=mit_pattern)

# %%
meas_filter = InvSGS(nbit+1, meas_fitter.cal_matrices, mit_pattern)
mit_counts_list = []
for counts in counts_list:
    x_tilde = meas_filter.apply(counts)
    mit_counts_list.append(x_tilde)
mit_hit_list = make_hit_list(mit_counts_list)
# Out:
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.999999999999999
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000002
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000009
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999991
# number of positive values:  121
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999983
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  133
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000002
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999998
# number of positive values:  129
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999989
# number of positive values:  129
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000004
# number of positive values:  129
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999997
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999998
# number of positive values:  130
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  129
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  125
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  121
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999992
# number of positive values:  123
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000004
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000009
# number of positive values:  130
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  130
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000002
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000002
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000004
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000009
# number of positive values:  125
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999998
# number of positive values:  129
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.000000000000001
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999996
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000002
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.000000000000001
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  130
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999998
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.000000000000001
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000013
# number of positive values:  130
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000004
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.000000000000001
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999997
# number of positive values:  125
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999998
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  125
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999999
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000002
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  129
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  130
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999996
# number of positive values:  129
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  130
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999998
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999997
# number of positive values:  129
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000004
# number of positive values:  132
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999999
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999996
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999996
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000004
# number of positive values:  131
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999996
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999999
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000009
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999997
# number of positive values:  129
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999998
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000002
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000009
# number of positive values:  125
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999998
# number of positive values:  129
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000002
# number of positive values:  125
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999981
# number of positive values:  129
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000009
# number of positive values:  130
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  125
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999998
# number of positive values:  124
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999999
# number of positive values:  124
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999996
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999997
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999998
# number of positive values:  131
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999991
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999992
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000004
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000009
# number of positive values:  125
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999994
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.000000000000001
# number of positive values:  135
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999999
# number of positive values:  130
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999993
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999987
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000007
# number of positive values:  124
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999987
# number of positive values:  125
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.999999999999998
# number of positive values:  130
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999992
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000004
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999999
# number of positive values:  134
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999986
# number of positive values:  123
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000004
# number of positive values:  128
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0000000000000004
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 1.0
# number of positive values:  126
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999998
# number of positive values:  127
# main process: Done!
# strict inverse + SGS algorithm
# sum of mitigated probability vector x: 0.9999999999999999
# number of positive values:  129
# main process: Done!

# %%
meas_filter = InvSSGS(nbit+1, meas_fitter.cal_matrices, mit_pattern)
x_tilde_S_list = [] # K = 0
for counts in counts_list:
    x_tilde = meas_filter.apply(counts)
    x_tilde_S_list.append(x_tilde)
mit_hit_S_list = make_hit_list(x_tilde_S_list)
print(mit_hit_S_list)
# Out:
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.128741148883432
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1280752075435174
# number of positive values:  8
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0645533114094181
# number of positive values:  9
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1397297453646482
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.06346390274846
# number of positive values:  9
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0913258910279948
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.099856792986657
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.084617980949418
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1101813626821948
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1101024252073821
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.117085351253768
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1243431643938522
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.114496633922115
# number of positive values:  20
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.143418195577115
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.125137482126317
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1234868321708187
# number of positive values:  23
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0699016371002787
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1314446923308732
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1142524339002835
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1444986025196375
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1835621529839995
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.2080918213108862
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.156173883989623
# number of positive values:  22
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1415896899926612
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1049414240665918
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1400287856431048
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.125443182180112
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1284185741991002
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.181037897490842
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1204963189985004
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.2083322634111726
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1910916251288097
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1510613600525985
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.185719737254584
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1408809239118227
# number of positive values:  21
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1293433967372113
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.186946317234609
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1424373431605228
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1172953777815735
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1243210287587624
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0980945847014558
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1030189955874394
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1107995317351325
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1105385181852943
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0708412222557535
# number of positive values:  17
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1319191458339641
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.146741537748876
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1226849277732047
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1703794718320686
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1147897560536018
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1084822870320705
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1331224167716698
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1935461848134319
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1292045524548593
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.184077582291212
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1417259028268583
# number of positive values:  22
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.095421943027816
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.174918000393208
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1510847209412487
# number of positive values:  17
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.111824453716522
# number of positive values:  17
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1662527600495396
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1888503894490559
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1514612814952085
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1024130495979418
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.191711069467324
# number of positive values:  17
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1150665887551774
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1441828087909185
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.148836658353487
# number of positive values:  22
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1423152101426366
# number of positive values:  17
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1172012313560185
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.126037051268372
# number of positive values:  22
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.132077982939914
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.142224375741854
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1180876175309533
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1229234708853324
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1178807979066114
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.078084224689012
# number of positive values:  6
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.103156737190851
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0956031205132175
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1281994868187901
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.162633517655105
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.125234997544579
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0592591314771203
# number of positive values:  9
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0709256890153274
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1019930015503427
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0944244264840441
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0906979368135863
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1128114288241615
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0771475739617962
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0547463343304735
# number of positive values:  8
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.093033914219283
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0886565826458587
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0801069362989306
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1224505411780246
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0706094545414702
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1296904868739848
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1180063062401377
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0929271300677157
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.0771214080723346
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + SGS algorithm
# sum of mitigated probability vector x_s: 1.1038268284216408
# number of positive values:  11
# main process: Done!
# [96.93583120686527, 99.68361256797374, 98.30726165971737, 75.96595802127518, 99.99999999999999, 93.91121989502788, 89.66914235971146, 95.0786004413223, 87.51280795868226, 83.20089435330102, 83.90408248615219, 91.92696966021765, 77.48144069749438, 86.1730635292519, 75.57645236131069, 66.55238916623428, 68.2804283410613, 74.3028206562745, 55.51476030011141, 55.62886503660991, 53.44831583460072, 51.26564689844062, 40.788216461738216, 43.8903723168127, 34.71247403390813, 40.44169071412603, 41.82930416602746, 23.45378039971643, 29.627243101718616, 13.752485047224033, 13.043943702904576, 11.10349830677866, 8.954166312084705, 11.46238409713437, 4.616790859237471, 7.115349733807781, 4.090000822596199, 7.718602101714739, 4.514281612439387, 1.8102072218280973, 0, 2.406606612410874, 4.04843897349332, 0, 0, 0, 0, 1.281072641984048, 0.9948466727271547, 0, 1.4353492496785902, 5.302549083456938, 6.845850811939223, 12.064575985708363, 19.38746311075235, 15.804647589767368, 17.199515745059397, 21.960564984004062, 22.438914552493035, 31.488889638015316, 38.343647694661556, 26.65660378875344, 39.45751096878225, 40.42832802578042, 35.28636336154036, 50.00946565155356, 65.8568246741581, 47.73489286169335, 53.4598315066149, 71.60758601407247, 61.78395922012262, 76.6622881354156, 68.37218836777328, 79.73516809623159, 77.08463379899726, 93.93727542774718, 91.82856305579008, 86.77479616305803, 91.1565346501795, 99.73376988335012, 100.0, 83.01102152048092, 100.0, 98.43850323595942, 92.20490646245112, 94.19235379254062, 94.49980150637813, 84.90274408481021, 96.11235967587588, 100.0, 93.7779908000263, 95.60095071332417, 98.85801868509397, 85.6191840012278, 100.0, 85.58598181671313, 78.86952261023193, 81.94678044588511, 89.11296886222823, 86.8752075729995]

# %%
meas_filter = InvSLM0SGS(nbit+1, meas_fitter.cal_matrices, mit_pattern)
x_tilde_S_lm_0_list = [] # K = 0
for counts in counts_list:
    x_tilde = meas_filter.apply(counts)
    x_tilde_S_lm_0_list.append(x_tilde)
mit_hit_S_lm_0_list = make_hit_list(x_tilde_S_lm_0_list)
print(mit_hit_S_lm_0_list)
# Out:
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.128741148883432
# sum of mitigated probability vector x_hat_s: 1.1286844357853734
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1280752075435174
# sum of mitigated probability vector x_hat_s: 1.1280229546289147
# number of positive values:  8
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0645533114094181
# sum of mitigated probability vector x_hat_s: 1.064494272057618
# number of positive values:  9
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1397297453646482
# sum of mitigated probability vector x_hat_s: 1.1396721868448088
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.06346390274846
# sum of mitigated probability vector x_hat_s: 1.0633673268391919
# number of positive values:  9
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0913258910279948
# sum of mitigated probability vector x_hat_s: 1.0911922648192895
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.099856792986657
# sum of mitigated probability vector x_hat_s: 1.0997946390275894
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.084617980949418
# sum of mitigated probability vector x_hat_s: 1.0845308473330517
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1101813626821948
# sum of mitigated probability vector x_hat_s: 1.1101032561582076
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1101024252073821
# sum of mitigated probability vector x_hat_s: 1.1099852570189974
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.117085351253768
# sum of mitigated probability vector x_hat_s: 1.1170289679830232
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1243431643938522
# sum of mitigated probability vector x_hat_s: 1.124302458958175
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.114496633922115
# sum of mitigated probability vector x_hat_s: 1.1143508159371427
# number of positive values:  20
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.143418195577115
# sum of mitigated probability vector x_hat_s: 1.1433251059458263
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.125137482126317
# sum of mitigated probability vector x_hat_s: 1.1249531511053248
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1234868321708187
# sum of mitigated probability vector x_hat_s: 1.1232865905154805
# number of positive values:  23
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0699016371002787
# sum of mitigated probability vector x_hat_s: 1.0697409109305163
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1314446923308732
# sum of mitigated probability vector x_hat_s: 1.1312618458582993
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1142524339002835
# sum of mitigated probability vector x_hat_s: 1.1139921583137036
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1444986025196375
# sum of mitigated probability vector x_hat_s: 1.1442275158274846
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1835621529839995
# sum of mitigated probability vector x_hat_s: 1.1833077917928025
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.2080918213108862
# sum of mitigated probability vector x_hat_s: 1.2079275350716023
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.156173883989623
# sum of mitigated probability vector x_hat_s: 1.1558312471981078
# number of positive values:  22
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1415896899926612
# sum of mitigated probability vector x_hat_s: 1.141248190882274
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1049414240665918
# sum of mitigated probability vector x_hat_s: 1.1046603352277342
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1400287856431048
# sum of mitigated probability vector x_hat_s: 1.1397637701032393
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.125443182180112
# sum of mitigated probability vector x_hat_s: 1.1251393921289592
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1284185741991002
# sum of mitigated probability vector x_hat_s: 1.1281172089002487
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.181037897490842
# sum of mitigated probability vector x_hat_s: 1.1807537539459374
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1204963189985004
# sum of mitigated probability vector x_hat_s: 1.120172690678217
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.2083322634111726
# sum of mitigated probability vector x_hat_s: 1.207957033391363
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1910916251288097
# sum of mitigated probability vector x_hat_s: 1.1908492778835602
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1510613600525985
# sum of mitigated probability vector x_hat_s: 1.1506878355876016
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.185719737254584
# sum of mitigated probability vector x_hat_s: 1.185346087194012
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1408809239118227
# sum of mitigated probability vector x_hat_s: 1.1404878323760077
# number of positive values:  21
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1293433967372113
# sum of mitigated probability vector x_hat_s: 1.1289650724267948
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.186946317234609
# sum of mitigated probability vector x_hat_s: 1.18661555582766
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1424373431605228
# sum of mitigated probability vector x_hat_s: 1.1421318424060143
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1172953777815735
# sum of mitigated probability vector x_hat_s: 1.1169062143892114
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1243210287587624
# sum of mitigated probability vector x_hat_s: 1.123960890138791
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0980945847014558
# sum of mitigated probability vector x_hat_s: 1.0977552825678276
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1030189955874394
# sum of mitigated probability vector x_hat_s: 1.102629614006035
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1107995317351325
# sum of mitigated probability vector x_hat_s: 1.1104926494957508
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1105385181852943
# sum of mitigated probability vector x_hat_s: 1.1100920977106492
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0708412222557535
# sum of mitigated probability vector x_hat_s: 1.0703213688150188
# number of positive values:  17
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1319191458339641
# sum of mitigated probability vector x_hat_s: 1.1316479060421496
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.146741537748876
# sum of mitigated probability vector x_hat_s: 1.146371060102165
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1226849277732047
# sum of mitigated probability vector x_hat_s: 1.122204468728948
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1703794718320686
# sum of mitigated probability vector x_hat_s: 1.169970107917859
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1147897560536018
# sum of mitigated probability vector x_hat_s: 1.114448876376801
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1084822870320705
# sum of mitigated probability vector x_hat_s: 1.108094232894138
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1331224167716698
# sum of mitigated probability vector x_hat_s: 1.1327482573351915
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1935461848134319
# sum of mitigated probability vector x_hat_s: 1.1932498502677036
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1292045524548593
# sum of mitigated probability vector x_hat_s: 1.1288720999373738
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.184077582291212
# sum of mitigated probability vector x_hat_s: 1.1836863273359137
# number of positive values:  18
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1417259028268583
# sum of mitigated probability vector x_hat_s: 1.1413434944466805
# number of positive values:  22
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.095421943027816
# sum of mitigated probability vector x_hat_s: 1.0950875641783795
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.174918000393208
# sum of mitigated probability vector x_hat_s: 1.1746258457170193
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1510847209412487
# sum of mitigated probability vector x_hat_s: 1.1506989238736411
# number of positive values:  17
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.111824453716522
# sum of mitigated probability vector x_hat_s: 1.1114758850379751
# number of positive values:  17
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1662527600495396
# sum of mitigated probability vector x_hat_s: 1.1659869641794216
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1888503894490559
# sum of mitigated probability vector x_hat_s: 1.1884520309584192
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1514612814952085
# sum of mitigated probability vector x_hat_s: 1.1513041666258244
# number of positive values:  19
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1024130495979418
# sum of mitigated probability vector x_hat_s: 1.102178040573058
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.191711069467324
# sum of mitigated probability vector x_hat_s: 1.1914626805127218
# number of positive values:  17
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1150665887551774
# sum of mitigated probability vector x_hat_s: 1.1148238088507836
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1441828087909185
# sum of mitigated probability vector x_hat_s: 1.1439763877428617
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.148836658353487
# sum of mitigated probability vector x_hat_s: 1.148468074896825
# number of positive values:  22
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1423152101426366
# sum of mitigated probability vector x_hat_s: 1.142050032352043
# number of positive values:  17
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1172012313560185
# sum of mitigated probability vector x_hat_s: 1.1170340728079544
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.126037051268372
# sum of mitigated probability vector x_hat_s: 1.1257844743770373
# number of positive values:  22
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.132077982939914
# sum of mitigated probability vector x_hat_s: 1.1319186343837717
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.142224375741854
# sum of mitigated probability vector x_hat_s: 1.1420906126755672
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1180876175309533
# sum of mitigated probability vector x_hat_s: 1.1179378367165707
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1229234708853324
# sum of mitigated probability vector x_hat_s: 1.122762801295833
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1178807979066114
# sum of mitigated probability vector x_hat_s: 1.11772142399861
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.078084224689012
# sum of mitigated probability vector x_hat_s: 1.0779715166662573
# number of positive values:  6
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.103156737190851
# sum of mitigated probability vector x_hat_s: 1.1030342149675778
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0956031205132175
# sum of mitigated probability vector x_hat_s: 1.0954915835371584
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1281994868187901
# sum of mitigated probability vector x_hat_s: 1.128106652022625
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.162633517655105
# sum of mitigated probability vector x_hat_s: 1.162538026534639
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.125234997544579
# sum of mitigated probability vector x_hat_s: 1.1251363787028663
# number of positive values:  15
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0592591314771203
# sum of mitigated probability vector x_hat_s: 1.0591968158688927
# number of positive values:  9
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0709256890153274
# sum of mitigated probability vector x_hat_s: 1.070926049088425
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1019930015503427
# sum of mitigated probability vector x_hat_s: 1.1019119533942554
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0944244264840441
# sum of mitigated probability vector x_hat_s: 1.094358117452704
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0906979368135863
# sum of mitigated probability vector x_hat_s: 1.0906600388812009
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1128114288241615
# sum of mitigated probability vector x_hat_s: 1.1127408135761154
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0771475739617962
# sum of mitigated probability vector x_hat_s: 1.0771210307352925
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0547463343304735
# sum of mitigated probability vector x_hat_s: 1.0546744265661827
# number of positive values:  8
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.093033914219283
# sum of mitigated probability vector x_hat_s: 1.0929857443348052
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0886565826458587
# sum of mitigated probability vector x_hat_s: 1.0885617975067003
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0801069362989306
# sum of mitigated probability vector x_hat_s: 1.0800287119329282
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1224505411780246
# sum of mitigated probability vector x_hat_s: 1.1223963749722943
# number of positive values:  11
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0706094545414702
# sum of mitigated probability vector x_hat_s: 1.0705274826338136
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1296904868739848
# sum of mitigated probability vector x_hat_s: 1.129627287936323
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1180063062401377
# sum of mitigated probability vector x_hat_s: 1.1180028116407046
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0929271300677157
# sum of mitigated probability vector x_hat_s: 1.0927545628480908
# number of positive values:  16
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0771214080723346
# sum of mitigated probability vector x_hat_s: 1.076985668285951
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.1038268284216408
# sum of mitigated probability vector x_hat_s: 1.1037432242822878
# number of positive values:  11
# main process: Done!
# [96.93583449935723, 99.68361026757808, 98.30725792158233, 75.96595378756099, 99.99999999999999, 93.91120814166885, 89.66914216884206, 95.07859558766357, 87.5128123962738, 83.20088441075359, 83.90408503924218, 91.92696794675065, 77.48144045252103, 86.17306069550116, 75.57644940277515, 66.55239598768401, 68.28042256284482, 74.30281019285738, 55.51477011209002, 55.628856207865155, 53.44830994128703, 51.265643311966656, 40.78822322614163, 43.890378964191406, 34.712458637577036, 40.44171342192855, 41.82929162976484, 23.45378452945622, 29.627239236286496, 13.752476705737829, 13.043927978105893, 11.103503061131976, 8.954170772852232, 11.462382244951666, 4.616790272051215, 7.1153284407488275, 4.090018135994217, 7.718573003524002, 4.514316394758473, 1.8102348836622286, 0, 2.4066033520300305, 4.048434478970757, 0, 0, 0, 0, 1.2810797768485052, 0.9948341818424836, 0, 1.4353181989624608, 5.302561437856981, 6.845879809994503, 12.064555911589261, 19.387454830598514, 15.804636125920482, 17.19951828382099, 21.960579638381773, 22.438926213409978, 31.488900131295182, 38.343623426110426, 26.656596227367235, 39.45750547094198, 40.42833580907413, 35.28635873303587, 50.00946248909328, 65.85682190458846, 47.73488244861532, 53.45983290563462, 71.60757467293945, 61.783943331635726, 76.66228494311626, 68.37218974313481, 79.73516408756835, 77.08463993661941, 93.9372755249211, 91.82855846734432, 86.77479618635319, 91.15654513760443, 99.73378380307736, 99.99999999999999, 83.01101333790812, 99.99999999999999, 98.43850324571139, 92.20490217698811, 94.1923481808685, 94.49979882792066, 84.90273792711915, 96.11235876017578, 99.99999999999999, 93.77798668909377, 95.60094481802571, 98.8580136218418, 85.61917959644164, 100.0, 85.58598151936144, 78.86952249211477, 81.94679799494068, 89.11296067022766, 86.87520354158217]

# %%
import pickle
with open("hit_list_p005_q005_piover100.pkl", "wb") as f:
    pickle.dump(hit_list, f)

# %%
import pickle
with open("mit_hit_list_p005_q005_piover100.pkl", "wb")as f:
    pickle.dump(mit_hit_list, f)

# %%
import pickle
with open("mit_hit_S_list_p005_q005_piover100.pkl", "wb")as f:
    pickle.dump(mit_hit_S_list, f)

# %%
import pickle
with open("mit_hit_S_lm_0_list_p005_q005_piover100.pkl", "wb")as f:
    pickle.dump(mit_hit_S_lm_0_list, f)

# %%
divide = 100
number_grover_list = [i for i in range(100)]
plt.plot(np.linspace(0,number_grover_list[-1], divide), 100 * np.cos(2 * np.linspace(0,number_grover_list[-1], divide) * np.arccos(np.sqrt(discretizedResult))) ** 2, label="theoretical curve", color="blue")
plt.plot(number_grover_list, hit_list, marker="o", label="results with readout error", color="green")
plt.plot(number_grover_list, mit_hit_list, marker="x", label="mitigated results", color="orange")
plt.plot(number_grover_list, mit_hit_S_list, marker="*", label="mitigated results (+S)", color="red")
plt.plot(number_grover_list, mit_hit_S_lm_0_list, marker="v", label="mitigated results (+S +LM0)", color="purple")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=18)
plt.title("7qubit, p(0->1): 0.05, p(1->0): 0.05")
plt.xlabel("number of grover iterations $m$")
plt.ylabel("number of shots for $|00...0>$")
# Out:
# Text(0, 0.5, 'number of shots for $|00...0>$')

# %%
def CalcErrorCramérRao(M, shot_list, p0, number_grover_list):
    """
        calculate Cramér-Rao lower bound
            M: upper limit of the sum in Fisher information 
            shots_list:  list of number of shots
            p0: the true parameter value to be estimated
            numebr_grover_list: list of number of Grover operators        

        Return:
            square root of Cramér-Rao lower bound:  lower bound on the standard deviation of unbiased estimators
    """
    FisherInfo = 0
    for k in range(M + 1):
        Nk = shot_list[k]
        mk = number_grover_list[k]
        FisherInfo += Nk / (p0 * (1 - p0)) * (2 * mk + 1)**2
    return np.sqrt(1 / FisherInfo)


def CalcNumberOracleCalls(M, shot_list, number_grover_list):
    """
        calculate the total number of oracle calls
            M: upper limit of the sum in Fisher information 
            shots_list:  list of number of shots
            numebr_grover_list: list of number of Grover operators        

        Return:
            Norac: the total number of oracle calls
    """
    Norac = 0
    for k in range(M + 1):
        Nk = shots_list[k]
        mk = number_grover_list[k]
        Norac += Nk * (2 * mk + 1)
    return Norac

def calculate_theta(hit_list, number_grover_list, shots_list):
    """
        calculate optimal theta values
            hit_list: list of count of obserbving "1" for qc_list
            numebr_grover_list: list of number of Grover operators        
            shots_list: list of number of shots

        Return:
            thetaCandidate_list: list of optimal theta
    """

    small = 1.e-15  # small valued parameter to avoid zero division
    confidenceLevel = 5  # confidence level to determine the search range

    thetaCandidate_list = []
    rangeMin = 0.0 + small
    rangeMax = 1.0 - small
    for igrover in range(len(number_grover_list)):

        def loglikelihood(p): # search value
            ret = np.zeros_like(p)
            theta = np.arcsin(np.sqrt(p)) # search theta
            for n in range(igrover + 1):
                ihit = hit_list[n] # empirical value
                arg = (2 * number_grover_list[n] + 1) * theta # search angle
                ret = ret + 2 * ihit * np.log(np.abs(np.sin(arg))) + 2 * (
                    shots_list[n] - ihit) * np.log(np.abs(np.cos(arg))) # search log likelihood
            return -ret

        searchRange = (rangeMin, rangeMax)
        searchResult = optimize.brute(loglikelihood, [searchRange])
        pCandidate = searchResult[0]
        thetaCandidate_list.append(np.arcsin(np.sqrt(pCandidate)))
        perror = CalcErrorCramérRao(igrover, shots_list, pCandidate, number_grover_list)
        rangeMax = min(pCandidate+confidenceLevel*perror,1.0 - small)
        rangeMin = max(pCandidate-confidenceLevel*perror,0.0 + small)
    return thetaCandidate_list

# %%
sin_hit_list = [100 - h for h in hit_list]
sin_mit_hit_list = [100 - h for h in mit_hit_list]
sin_mit_hit_S_list = [100 - h for h in mit_hit_S_list]
sin_mit_hit_S_lm_0_list = [100 - h for h in mit_hit_S_lm_0_list]

thetaCandidate_list = calculate_theta(
    sin_hit_list, number_grover_list, shots_list)  # list of estimated theta values
thetaCandidate_mit_list = calculate_theta(
    sin_mit_hit_list, number_grover_list, shots_list)  # list of estimated theta values
thetaCandidate_mit_S_list = calculate_theta(
    sin_mit_hit_S_list, number_grover_list, shots_list)  # list of estimated theta values
thetaCandidate_mit_S_lm_0_list = calculate_theta(
    sin_mit_hit_S_lm_0_list, number_grover_list, shots_list)  # list of estimated theta values

error_list = np.abs(np.sin(thetaCandidate_list)**2 - discretizedResult)  # list of estimation errors
error_mit_list = np.abs(np.sin(thetaCandidate_mit_list)**2 - discretizedResult)  # list of estimation errors
error_mit_S_list = np.abs(np.sin(thetaCandidate_mit_S_list)**2 - discretizedResult)  # list of estimation errors
error_mit_S_lm_0_list = np.abs(np.sin(thetaCandidate_mit_S_lm_0_list)**2 - discretizedResult)  # list of estimation errors
OracleCall_list = []  # list of number of oracle calls
ErrorCramérRao_list = []  # list of Cramér-Rao lower bound
for i in range(len(number_grover_list)):
    OracleCall_list.append(
        CalcNumberOracleCalls(i, shots_list, number_grover_list))
    ErrorCramérRao_list.append(
        CalcErrorCramérRao(i, shots_list, discretizedResult, number_grover_list))

p = plt.plot( OracleCall_list, ErrorCramérRao_list)
p0 = plt.plot( OracleCall_list, error_list, 'o')
p1 = plt.plot( OracleCall_list, error_mit_list, '*', color='C4')
p2 = plt.plot( OracleCall_list, error_mit_S_list, 'x', color='C2')
p3 = plt.plot( OracleCall_list, error_mit_S_lm_0_list, 'v', color='C3')

plt.title("7qubit, p(0->1): 0.05, p(1->0): 0.05")
plt.xscale('log')
plt.xlabel("Number of oracle calls")
plt.ylim(0.00000001, 1)
plt.yscale('log')
plt.ylabel("Estimation Error")
plt.legend((p[0], p0[0], p1[0], p2[0], p3[0]), ("Cramér-Rao", "with readout error", "mitigated", "mitigated (+S)", "mitigated (+S +LM)"))
plt.show()
