# %% [markdown]
# ### Approximating the integral
#
# It is easy to see that as we use large $n$ (i.e., more qubits) and thus larger $b_{\mbox{max}}$, we can approximate the integral better as illustrated below.

# %%
import math

b_max = math.pi / 100  # upper limit of integral # 5
nbit = 10  # change this value to get discretized result closer to analytical results # 3

analyticResult = (b_max / 2.0 - math.sin(2 * b_max) / 4.0 ) / b_max  # the target integral can be analytically solved
print("Analytical Result:", analyticResult)

ndiv = 2**nbit  #number of discretization 
discretizedResult = 0.0
for i in range(ndiv):
    discretizedResult += math.sin(b_max / ndiv * (i + 0.5))**2
discretizedResult = discretizedResult / ndiv
print("Discretized Result:", discretizedResult)
# Out:
# Analytical Result: 0.00032892188007938847
# Discretized Result: 0.0003289218016943769

# %% [markdown]
# ### Grover Operators for Amplitude Estimation
#
# We can easily build quantum circuits for fast computation of the Monte Carlo integration as below. Here, we show functions to construct quantum circuits running with simulators. Running them on real devices should be easy by adjusting the parameters of the functions.

# %%
import sys
sys.path.append('../../libmitigation')

# %%
#Preparing qiskit environment
from qiskit import ClassicalRegister, QuantumRegister, QuantumCircuit
from qiskit import execute
from qiskit import IBMQ
from qiskit import Aer
from scipy import optimize
import sys, time
import mpmath as mp
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/yangbo/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/qiskit/__init__.py:67: DeprecationWarning: Using Qiskit with Python 3.6 is deprecated as of the 0.17.0 release. Support for running Qiskit with Python 3.6 will be removed in a future release.
#   "future release.", DeprecationWarning)

# %%
from qiskit.providers.aer.noise import NoiseModel
from qiskit.providers.aer.noise import QuantumError, ReadoutError
from qiskit.providers.aer.noise import depolarizing_error
import qiskit.ignis.mitigation as mit
from qiskit.ignis.mitigation.measurement import tensored_meas_cal, TensoredMeasFitter
import importlib
from inv_sgs import InvSGS
from inv_s_sgs import InvSSGS
from inv_lm_sgs import InvLMSGS
from inv_s_lm_sgs import InvSLMSGS
from inv_s_lm0_sgs import InvSLM0SGS
from inv_s_lmk_sgs import InvSLMkSGS
from mooney_etal import MooneyEtal
from sgs_algorithm import sgs_algorithm
from lib_grover import *

# %% [markdown]
# For example, quantum circuit with two Grover operators is shown below.

# %%
qc_list = create_grover_circuit([2], nbit, b_max)
my_style = {'usepiformat': True, 'cregbundle': True,'compress': True }
qc_list[0].draw(output="mpl", style=my_style, plot_barriers=False )
# Out:
# /Users/yangbo/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/qiskit/visualization/matplotlib.py:291: DeprecationWarning: style option/s (usepiformat, cregbundle, compress) is/are not supported
#   set_style(current_style, style)

# %% [markdown]
# ## Testing the algorithm with simulators
#
# Let us run the algorithm with simulators

# %%
#setting the number of shots and Grover operators.

# number_grover_list = [0, 1, 2, 4, 8, 16, 32] # , 64, 128, 256]  # list of number of Grover operators
number_grover_list = [i for i in range(20)]
shots = 100
shots_list = [shots] * len(number_grover_list) # list of number of shots
if len(shots_list) != len(number_grover_list):
    raise Exception(
        'The length of shots_list should be equal to the length of number_grover_list.'
    )

backend = Aer.get_backend('qasm_simulator')

# %%
noise_model = NoiseModel()
for qi in range(nbit+1):
    if qi >= 0:
        read_err = ReadoutError([[0.990, 0.010],[0.010,0.990]])
        noise_model.add_readout_error(read_err, [qi])

# %% [markdown]
# Finally, we can run the algorithm as below:

# %%
qc_list = create_grover_circuit(number_grover_list, nbit,b_max)  # list of Grover circuits

# %%
counts_list = run_grover(qc_list, number_grover_list, shots_list, backend, noise_model=noise_model)  # list of number of grover operators
# Out:
# 0 th round with 0 oracles
# 0.5574679374694824 s
# 1 th round with 1 oracles
# 0.015944957733154297 s
# 2 th round with 2 oracles
# 0.021093130111694336 s
# 3 th round with 3 oracles
# 0.027511119842529297 s
# 4 th round with 4 oracles
# 0.03391385078430176 s
# 5 th round with 5 oracles
# 0.03920602798461914 s
# 6 th round with 6 oracles
# 0.04641890525817871 s
# 7 th round with 7 oracles
# 0.05233168601989746 s
# 8 th round with 8 oracles
# 0.061006784439086914 s
# 9 th round with 9 oracles
# 0.06819391250610352 s
# 10 th round with 10 oracles
# 0.07869195938110352 s
# 11 th round with 11 oracles
# 0.0796821117401123 s
# 12 th round with 12 oracles
# 0.08850717544555664 s
# 13 th round with 13 oracles
# 0.09640121459960938 s
# 14 th round with 14 oracles
# 0.10071301460266113 s
# 15 th round with 15 oracles
# 0.1087648868560791 s
# 16 th round with 16 oracles
# 0.2184000015258789 s
# 17 th round with 17 oracles
# 0.11495780944824219 s
# 18 th round with 18 oracles
# 0.12410092353820801 s
# 19 th round with 19 oracles
# 0.1338651180267334 s

# %%
hit_list = make_hit_list(counts_list)
print(hit_list)
# Out:
# [91, 92, 86, 84, 88, 88, 87, 77, 85, 83, 80, 78, 70, 73, 68, 71, 70, 56, 52, 54]

# %%
shots = 8192
qr = QuantumRegister(nbit+1)
mit_pattern = [[i] for i in range(nbit+1)]
meas_calibs, state_labels = tensored_meas_cal(mit_pattern=mit_pattern, qr=qr, circlabel='mcal')
job = execute(meas_calibs, backend=Aer.get_backend('qasm_simulator'), shots=shots, noise_model=noise_model)
cal_results = job.result()
meas_fitter = TensoredMeasFitter(cal_results, mit_pattern=mit_pattern)

# %%
meas_filter = InvSLM0SGS(nbit+1, meas_fitter.cal_matrices, mit_pattern)
x_tilde_S_lm_0_list = []
for counts in counts_list:
    x_tilde = meas_filter.apply(counts)
    x_tilde_S_lm_0_list.append(x_tilde)
mit_hit_S_lm_0_list = make_hit_list(x_tilde_S_lm_0_list)
print(mit_hit_S_lm_0_list)
# Out:
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0348378576482744
# sum of mitigated probability vector x_hat_s: 1.0348497657443076
# 0.0023980140686035156 s
# number of positive values:  8
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0525080497973127
# sum of mitigated probability vector x_hat_s: 1.0525169317539358
# 0.0016760826110839844 s
# number of positive values:  6
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0591294258431645
# sum of mitigated probability vector x_hat_s: 1.0591383743483564
# 0.0018329620361328125 s
# number of positive values:  7
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0279635446625124
# sum of mitigated probability vector x_hat_s: 1.0279785313311935
# 0.0038728713989257812 s
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0436011505983214
# sum of mitigated probability vector x_hat_s: 1.0436114213888867
# 0.0018739700317382812 s
# number of positive values:  8
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.056408072560208
# sum of mitigated probability vector x_hat_s: 1.0564215269281765
# 0.002788066864013672 s
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0459657429905107
# sum of mitigated probability vector x_hat_s: 1.0459777144411755
# 0.0021660327911376953 s
# number of positive values:  9
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0450103908552322
# sum of mitigated probability vector x_hat_s: 1.0450251482340305
# 0.0035009384155273438 s
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0473735954845276
# sum of mitigated probability vector x_hat_s: 1.0473868614329993
# 0.0027489662170410156 s
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0686630115593863
# sum of mitigated probability vector x_hat_s: 1.0686721826093735
# 0.0016167163848876953 s
# number of positive values:  7
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0591958591659152
# sum of mitigated probability vector x_hat_s: 1.0592061953595362
# 0.001972198486328125 s
# number of positive values:  8
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0576406343615812
# sum of mitigated probability vector x_hat_s: 1.0576527617437899
# 0.0027790069580078125 s
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0612566688384693
# sum of mitigated probability vector x_hat_s: 1.061272025454388
# 0.004848957061767578 s
# number of positive values:  13
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0696429278527215
# sum of mitigated probability vector x_hat_s: 1.0696570975742201
# 0.0038208961486816406 s
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0707798917236302
# sum of mitigated probability vector x_hat_s: 1.0707967305441053
# 0.005053043365478516 s
# number of positive values:  14
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0613681905675671
# sum of mitigated probability vector x_hat_s: 1.061383040394304
# 0.003696918487548828 s
# number of positive values:  12
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0838873883487097
# sum of mitigated probability vector x_hat_s: 1.083896162052427
# 0.0015687942504882812 s
# number of positive values:  7
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0722664011030032
# sum of mitigated probability vector x_hat_s: 1.0722778901555443
# 0.0026450157165527344 s
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.0720794257250128
# sum of mitigated probability vector x_hat_s: 1.0720918339365162
# 0.0029659271240234375 s
# number of positive values:  10
# main process: Done!
# Restriction to labels of y + Lagrange Multiplier + SGS algorithm
# sum of mitigated probability vector x_s: 1.073546675997288
# sum of mitigated probability vector x_hat_s: 1.0735586283775382
# 0.0023610591888427734 s
# number of positive values:  9
# main process: Done!
# [100.0, 100.0, 94.66980328165425, 93.22090502505802, 97.05557375793953, 97.22413281559508, 96.17453841610123, 85.21101999637244, 94.01005420267748, 90.43356635777646, 87.77818666161117, 86.0712398118464, 77.27923463404056, 80.53643237824166, 75.05846413829204, 78.31212210749334, 76.08473013211065, 61.26011353800245, 56.633112733250194, 58.74873716841466]

# %%
meas_filter = MooneyEtal(nbit+1, meas_fitter.cal_matrices, mit_pattern)
x_tilde_mooney_list = []
for counts in counts_list:
    x_tilde = meas_filter.apply(counts, threshold=1/100)
    x_tilde_mooney_list.append(x_tilde)
mit_hit_mooney100_list = make_hit_list(x_tilde_mooney_list)
print(mit_hit_mooney100_list)
# Out:
# The heuristcs by Mooney et al. + SGS algorithm
# {32: 0.011533894813600893, 0: 1.0138377595442678}
# sum of counts: 1.0253716543578686
# 0.0006771087646484375 s
# number of positive values:  2
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 1.025140115224999, 64: 0.013186503625537143, 8: 0.011282573705251845}
# sum of counts: 1.049609192555788
# 0.0004558563232421875 s
# number of positive values:  3
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {1: 0.01200942383169967, 1024: 0.025285282839776498, 2: 0.03441896301485755, 16: 0.024595057573334758, 0: 0.9574573958860274}
# sum of counts: 1.0537661231456958
# 0.0005009174346923828 s
# number of positive values:  5
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {4: 0.011893489297111828, 1056: 0.010645546475070619, 264: 0.011042012581648013, 0: 0.9351417142823472, 1024: 0.01417828394537345, 32: 0.034524050419040664}
# sum of counts: 1.0174250970005918
# 0.0008261203765869141 s
# number of positive values:  6
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {4: 0.01139959299658402, 1: 0.011770005895549836, 512: 0.03458591199062091, 0: 0.9799999421772855}
# sum of counts: 1.0377554530600404
# 0.0005140304565429688 s
# number of positive values:  4
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {1152: 0.011210097705219597, 1792: 0.01121425674386662, 520: 0.010906053619393532, 32: 0.023032670211323755, 512: 0.012162848426083946, 0: 0.9804115175041961}
# sum of counts: 1.0489374442100836
# 0.000614166259765625 s
# number of positive values:  6
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {1280: 0.010889073667639432, 32: 0.02315211125590942, 0: 0.9688296957575478, 512: 0.012387339355443344, 1024: 0.013875817088145306, 256: 0.013359658632131705}
# sum of counts: 1.042493695756817
# 0.0005528926849365234 s
# number of positive values:  6
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {1536: 0.01062179183590023, 128: 0.014939593959103077, 1027: 0.011183875682401945, 64: 0.03693231783653574, 256: 0.025687523249573675, 1024: 0.048307454429555745, 2: 0.024335336953568716, 0: 0.856461916984469}
# sum of counts: 1.0284698109311081
# 0.0007872581481933594 s
# number of positive values:  8
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
#
nbit+1, meas_fitter.cal_matrices, mit_pattern)
x_tilde_mooney_list = []
for counts in counts_list:
    x_tilde = meas_filter.apply(counts, threshold=1/10)
    x_tilde_mooney_list.append(x_tilde)
mit_hit_mooney10_list = make_hit_list(x_tilde_mooney_list)
print(mit_hit_mooney10_list)
# Out:
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 1.014849976419478}
# sum of counts: 1.014849976419478
# 0.0003972053527832031 s
# number of positive values:  1
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 1.0258824649944742}
# sum of counts: 1.0258824649944742
# 0.000186920166015625 s
# number of positive values:  1
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.9588495707679723}
# sum of counts: 0.9588495707679723
# 0.00020003318786621094 s
# number of positive values:  1
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.9366648846499046}
# sum of counts: 0.9366648846499046
# 0.00023818016052246094 s
# number of positive values:  1
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.9811539658541146}
# sum of counts: 0.9811539658541146
# 0.00020503997802734375 s
# number of positive values:  1
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.9813933837902644}
# sum of counts: 0.9813933837902644
# 0.00026988983154296875 s
# number of positive values:  1
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.970241186247193}
# sum of counts: 0.970241186247193
# 0.0001919269561767578 s
# number of positive values:  1
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.8585995018484065}
# sum of counts: 0.8585995018484065
# 0.00020003318786621094 s
# number of positive values:  1
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.9479367911610509}
# sum of counts: 0.9479367911610509
# 0.00018787384033203125 s
# number of positive values:  1
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.9241624276032027, 1024: 0.11507910625915042}
# sum of counts: 1.039241533862353
# 0.00021791458129882812 s
# number of positive values:  2
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.8920560944776201}
# sum of counts: 0.8920560944776201
# 0.00016307830810546875 s
# number of positive values:  1
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.8697516993914779}
# sum of counts: 0.8697516993914779
# 0.00031280517578125 s
# number of positive values:  1
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.7785171264934332, 1024: 0.17215964557349403}
# sum of counts: 0.9506767720669272
# 0.00027298927307128906 s
# number of positive values:  2
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.8121073526200749, 1024: 0.160680941443924}
# sum of counts: 0.9727882940639989
# 0.0002961158752441406 s
# number of positive values:  2
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.7566121974622797, 1024: 0.13890444341911007}
# sum of counts: 0.8955166408813897
# 0.0004899501800537109 s
# number of positive values:  2
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.7898029575339324, 1024: 0.160873814532995}
# sum of counts: 0.9506767720669274
# 0.0002620220184326172 s
# number of positive values:  2
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.7781147915638549, 1024: 0.2058479373058198}
# sum of counts: 0.9839627288696746
# 0.00022411346435546875 s
# number of positive values:  2
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {1024: 0.26302801864750264, 0: 0.6209581660067901}
# sum of counts: 0.8839861846542927
# 0.00033783912658691406 s
# number of positive values:  2
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.5752510243590822, 1024: 0.3754257477078456}
# sum of counts: 0.9506767720669278
# 0.00023984909057617188 s
# number of positive values:  2
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# The heuristcs by Mooney et al. + SGS algorithm
# {0: 0.5980760289055826, 1024: 0.3416636559699495}
# sum of counts: 0.9397396848755322
# 0.0002319812774658203 s
# number of positive values:  2
# accumulator is positive, we might even ignoring the necessal positive values.
# main process: Done!
# [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 90.4541660672026, 100.0, 100.0, 80.31787404599694, 82.57132055880754, 80.88538770215848, 81.44645715004687, 78.61334271290175, 67.89650736796438, 59.99126383256183, 62.820618646781654]

# %%
divide = 20
plt.plot(np.linspace(0,number_grover_list[-1], divide), shots * np.cos(2 * np.linspace(0,number_grover_list[-1], divide) * np.arccos(np.sqrt(discretizedResult))) ** 2, label="Heisenberg limit", color="blue")
plt.plot(number_grover_list, hit_list, marker="o", label="noisy output")
plt.plot(number_grover_list, mit_hit_S_lm_0_list, marker="v", label="proposed method", color="C3")
plt.plot(number_grover_list, mit_hit_mooney100_list, marker="*", label="Mooney et al. (t=1/100)", color="C2")
plt.plot(number_grover_list, mit_hit_mooney10_list, marker="*", label="Mooney et al. (t=1/10)", color="C5")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=18)
plt.title("20qubit, p(0->1): 0.01, p(1->0): 0.01")
plt.xlabel("number of grover iterations $m$")
plt.ylabel("number of shots for $|00...0>$")
# Out:
# Text(0, 0.5, 'number of shots for $|00...0>$')

# %%
sin_hit_list = [shots - h for h in hit_list]
sin_mit_hit_S_lm_0_list = [shots - h for h in mit_hit_S_lm_0_list]
sin_mit_hit_mooney100_list = [shots - h for h in mit_hit_mooney100_list]
sin_mit_hit_mooney10_list = [shots - h for h in mit_hit_mooney10_list]

thetaCandidate_list = calculate_theta(
    sin_hit_list, number_grover_list, shots_list)  # list of estimated theta values
thetaCandidate_mit_S_lm_0_list = calculate_theta(
    sin_mit_hit_S_lm_0_list, number_grover_list, shots_list)  # list of estimated theta values
thetaCandidate_mit_mooney100_list = calculate_theta(
    sin_mit_hit_mooney100_list, number_grover_list, shots_list)  # list of estimated theta values
thetaCandidate_mit_mooney10_list = calculate_theta(
    sin_mit_hit_mooney10_list, number_grover_list, shots_list)  # list of estimated theta values

error_list = np.abs(np.sin(thetaCandidate_list)**2 - discretizedResult)  # list of estimation errors
error_mit_S_lm_0_list = np.abs(np.sin(thetaCandidate_mit_S_lm_0_list)**2 - discretizedResult)  # list of estimation errors
error_mit_mooney100_list = np.abs(np.sin(thetaCandidate_mit_mooney100_list)**2 - discretizedResult)  # list of estimation errors
error_mit_mooney10_list = np.abs(np.sin(thetaCandidate_mit_mooney10_list)**2 - discretizedResult)  # list of estimation errors
OracleCall_list = []  # list of number of oracle calls
ErrorCramérRao_list = []  # list of Cramér-Rao lower bound
for i in range(len(number_grover_list)):
    OracleCall_list.append(
        CalcNumberOracleCalls(i, shots_list, number_grover_list))
    ErrorCramérRao_list.append(
        CalcErrorCramérRao(i, shots_list, discretizedResult, number_grover_list))

# %%
plt.clf()
p = plt.loglog( OracleCall_list, ErrorCramérRao_list)
p0 = plt.loglog( OracleCall_list, error_list, 'o', markersize=3)
p2 = plt.loglog( OracleCall_list, error_mit_mooney100_list, 'x', color='C2', markersize=4)
p3 = plt.loglog( OracleCall_list, error_mit_S_lm_0_list, 'v', color='C3', markersize=2)
p4 = plt.loglog( OracleCall_list, error_mit_mooney10_list, 'x', color='C5', markersize=4)

plt.title("10qubit, p(0|1)=p(1|0)=0.01, b_max=π/100")
plt.xlim(OracleCall_list[0]*0.9, OracleCall_list[-1]*1.5)
plt.xlabel("Number of oracle calls")
plt.ylim(0.00000001, 1)
plt.ylabel("Estimation Error")
plt.grid(True, which="both", ls="dotted")
plt.legend((p[0], p0[0], p4[0], p2[0], p3[0]), ("Heisenberg limit", "noisy output", "Mooney et al. (t=1/10)", "Mooney et al. (t=1/100)", "proposed method"))
plt.show()

# %% [markdown]
# ## real device

# %%
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q-utokyo', group='internal', project='hirashi-jst')
print(provider)
# Out:
# <AccountProvider for IBMQ(hub='ibm-q-utokyo', group='internal', project='hirashi-jst')>

# %%
device = provider.backends.ibmq_montreal
# Out:
# /Users/yangbo/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The `backends` provider attribute is deprecated. Please use `provider.backend` (singular) instead. You can continue to use `provider.backends()` to retrieve all backends.
#   """Entry point for launching an IPython kernel.

# %%
shots = 100

# %%
initial_layout = [10,13,15,12]

# %%
job = execute(qc_list, backend=provider.get_backend("ibmq_montreal"), shots=shots, optimization_level=3, initial_layout=)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/qiskit/tools/parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     144                 param = map(lambda value: (task, value, task_args, task_kwargs), values)
# --> 145                 future = executor.map(_task_wrapper, param)
#     146
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     610     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 611         self.shutdown(wait=True)
#     612         return False
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/concurrent/futures/process.py in shutdown(self, wait)
#     505             if wait:
# --> 506                 self._queue_management_thread.join()
#     507         # To reduce the risk of opening too many files, remove references to
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/threading.py in join(self, timeout)
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# QiskitError                               Traceback (most recent call last)
# <ipython-input-24-8ddee8a76f58> in <module>
# ----> 1 job = execute(qc_list, backend=provider.get_backend("ibmq_montreal"), shots=shots, optimization_level=3)
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/qiskit/execute_function.py in execute(experiments, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, qobj_id, qobj_header, shots, memory, max_credits, seed_simulator, default_qubit_los, default_meas_los, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, parameter_binds, schedule_circuit, inst_map, meas_map, scheduling_method, init_qubits, **run_config)
#     257                                 seed_transpiler=seed_transpiler,
#     258                                 optimization_level=optimization_level,
# --> 259                                 backend=backend)
#     260
#     261     if schedule_circuit:
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/qiskit/compiler/transpiler.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     243
#     244     # Transpile circuits in parallel
# --> 245     circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#     246
#     247     end_time = time()
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/qiskit/tools/parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     152                 Publisher().publish("terra.parallel.finish")
#     153                 os.environ['QISKIT_IN_PARALLEL'] = 'FALSE'
# --> 154                 raise QiskitError('Keyboard interrupt in parallel_map.') from error
#     155             # Otherwise just reset parallel flag and error
#     156             os.environ['QISKIT_IN_PARALLEL'] = 'FALSE'
#
# QiskitError: 'Keyboard interrupt in parallel_map.'
